# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
from flask import Flask, jsonify
from pprint import pprint
import requests

import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import and_
from sqlalchemy.orm import sessionmaker
from sqlalchemy.orm import joinedload


import sqlalchemy as db

# %%
##### import dti for joseph
import debt_to_income as dti

# %%
dti_df = dti.debt_to_income_init()
dti_df.head()
# Out:
#         year area_fips  DtoI_low  DtoI_high     county_name    state
# 125482  2009      1005      1.01       1.19  Barbour County  Alabama
# 125483  2009      1007      2.16       2.63     Bibb County  Alabama
# 125485  2009      1011      1.58       1.82  Bullock County  Alabama
# 125486  2009      1013      1.37       1.58   Butler County  Alabama
# 125487  2009      1015      1.58       1.82  Calhoun County  Alabama

# %%
##### Dropping Extra Column and Renaming Columns to match SQL Schema
dti_df = dti.debt_to_income_init()
dti_df = dti_df.drop(columns=["area_fips"])
dti_df.columns = ["Year", "DtoI_low", "DtoI_high", "CountyName", "StateName"]

# %%
engine = create_engine("postgresql://postgres:etlpass@localhost:5432/marriage_debt")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['DebtToIncomeRatiosByQtr',
#  'MortgageCosts_time_permitting',
#  'Income_time_permitting',
#  'DebtToIncomeRatiosByYear',
#  'MaritalStatus']

# %%
##### Save references to each table
marriage = Base.classes.MaritalStatus
debtyr = Base.classes.DebtToIncomeRatiosByYear

# %%
##### dti_df.dropna().to_sql('DebtToIncomeRatiosByYear', con=engine, if_exists='append', index = False)
engine.execute('SELECT * FROM "DebtToIncomeRatiosByYear" limit 10').fetchall()
# Out:
# [(2009, 'Butte County', 'Idaho', 0.0, 0.78),
#  (2009, 'Barbour County', 'Alabama', 1.01, 1.19),
#  (2009, 'Bibb County', 'Alabama', 2.16, 2.63),
#  (2009, 'Bullock County', 'Alabama', 1.58, 1.82),
#  (2009, 'Butler County', 'Alabama', 1.37, 1.58),
#  (2009, 'Calhoun County', 'Alabama', 1.58, 1.82),
#  (2009, 'Chambers County', 'Alabama', 2.63, 3.46),
#  (2009, 'Cherokee County', 'Alabama', 2.16, 2.63),
#  (2009, 'Chilton County', 'Alabama', 2.63, 3.46),
#  (2009, 'Choctaw County', 'Alabama', 1.82, 2.16)]

# %%
##### import from Michael
import Marriage as mar
mar_df = mar.marriage_def()
mar_df.head()
# Out:
#   Total Population Percent Married Percent Widowed Percent Divorced  \
# 0            38213            54.6             5.9             11.9
# 1           138986            59.9             6.8             10.9
# 2            24159            43.5             8.4             11.6
# 3            17270            54.2             6.4             12.5
# 4            45255            55.8             8.0             13.1
#
#   Percent Separated Never Married Total Population Error  \
# 0               2.4          25.3                     80
# 1               1.7          20.6                     81
# 2               4.1          32.4                     17
# 3               3.2          23.6                  *****
# 4               2.6          20.5                    166
#
#   Percent Married Error Percent Widowed Error Percent Divorced Error  \
# 0                   2.0                   0.6                    1.3
# 1                   1.5                   0.5                    0.8
# 2                   2.7                   0.8                    1.5
# 3                   3.9                   1.1                    2.2
# 4                   2.4                   0.9                    1.5
#
#   Percent Separated Error Never Married Error          County    State  Year
# 0                     0.5                 1.2  Autauga County  Alabama  2009
# 1                     0.3                 0.8  Baldwin County  Alabama  2009
# 2                     1.1                 1.9  Barbour County  Alabama  2009
# 3                     1.3                 2.2     Bibb County  Alabama  2009
# 4                     0.5                 1.5   Blount County  Alabama  2009

# %%
##### Dropping Extra Columns and Renaming Columns to match SQL Schema
mar_df = mar_df.drop(columns=["Total Population", "Percent Widowed", "Total Population Error", "Percent Widowed Error"])
mar_df.columns = ["NowMarriedPct", "DivorcedPct", "SeparatedPct", "NeverMarriedPct", "NowMarriedError", "DivorcedError",
                  "SeparatedError", "NeverMarriedError", "CountyName", "StateName", "Year"]
mar_df.head()
# Out:
#   NowMarriedPct DivorcedPct SeparatedPct NeverMarriedPct NowMarriedError  \
# 0          54.6        11.9          2.4            25.3             2.0
# 1          59.9        10.9          1.7            20.6             1.5
# 2          43.5        11.6          4.1            32.4             2.7
# 3          54.2        12.5          3.2            23.6             3.9
# 4          55.8        13.1          2.6            20.5             2.4
#
#   DivorcedError SeparatedError NeverMarriedError      CountyName StateName  \
# 0           1.3            0.5               1.2  Autauga County   Alabama
# 1           0.8            0.3               0.8  Baldwin County   Alabama
# 2           1.5            1.1               1.9  Barbour County   Alabama
# 3           2.2            1.3               2.2     Bibb County   Alabama
# 4           1.5            0.5               1.5   Blount County   Alabama
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
##### The init function is not working
mar_df = mar.Marriage_Related_init()

# %%
#####
mar_df = mar_df.drop([0])
mar_df
##### Send data to Postgres SQL
mar_df.to_sql('MaritalStatus', engine, drop=index, if_exists='append')
# mar_df.to_sql('MaritalStatus', engine)
# Out:
#       NowMarriedPct DivorcedPct SeparatedPct NeverMarriedPct NowMarriedError  \
# 1              59.9        10.9          1.7            20.6             1.5
# 2              43.5        11.6          4.1            32.4             2.7
# 3              54.2        12.5          3.2            23.6             3.9
# 4              55.8        13.1          2.6            20.5             2.4
# 5              32.7         9.0          4.6            44.5             5.7
# 6              43.5        12.7          3.4            29.2             3.2
# 7              51.2        12.9          2.6            24.4             1.5
# 8              49.7        10.4          3.5            26.2             2.8
# 9              64.6         9.7          1.8            15.3             3.8
# 10             57.0        11.5          2.5            21.6             2.7
# 11             52.5        10.8          3.2            24.4             4.5
# 12             46.9        10.0          3.6            29.3             3.1
# 13             61.6         9.5          2.2            14.6             6.1
# 14             51.3        14.5          2.8            24.1             4.6
# 15             56.1        12.3          2.5            21.7             2.1
# 16             56.9        11.3          1.7            21.7             1.9
# 17             54.3        10.2          1.5            25.2             5.5
# 18             55.1        13.2          2.5            21.4             5.7
# 19             53.3        10.9          2.8            22.9             2.6
# 20             50.6        12.2          2.6            23.0             3.1
# 21             56.3        12.8          2.6            20.6             1.9
# 22             57.2        12.6          2.0            21.4             2.3
# 23             40.6        11.2          4.0            34.9             2.5
# 24             57.6        12.1          2.1            20.5             2.5
# 25             51.5        12.1          2.5            26.8             1.7
# 26             50.2        10.4          2.8            27.2             2.4
# 27             55.3        12.7          2.7            20.2             1.5
# 28             58.9        10.6          2.3            19.0             3.9
# 29             59.6        11.0          2.7            19.2             3.0
# 30             53.7        13.4          2.5            21.1             3.3
# ...             ...         ...          ...             ...             ...
# 28253          60.8        12.5          0.8            18.3             1.6
# 28254          59.8        10.3          0.7            23.5             1.1
# 28255          59.7         8.8          0.5            25.5             0.6
# 28256          54.6          12          1.3            24.3             1.6
# 28257          56.5          13          0.9            22.7             1.2
# 28258          48.2        11.9            1            33.5             0.9
# 28259          55.2        12.6          0.7            24.9             1.3
# 28260          41.1           8          0.6            47.4             1.7
# 28261          54.6        11.6          1.3            25.1             3.4
# 28262          57.3          11          2.1            26.6             2.8
# 28263          54.7        13.3          1.7            25.3               3
# 28264          60.4        14.4          0.5              19             4.4
# 28265          67.5         9.9          0.2            17.5             4.7
# 28266          49.3        14.1          1.4            28.3               2
# 28267          58.6        12.2          0.6              22             3.3
# 28268          58.9        15.3          0.4              17             5.4
# 28269          56.6        14.6            0              20             4.6
# 28270          52.5        13.7          1.8            26.7             1.6
# 28271          60.4        10.7          1.8            21.9             3.5
# 28272          50.5        14.8          1.3            27.5             1.8
# 28273          49.9        13.1          2.5            26.1             6.5
# 28274            58        10.3            1            25.2             3.1
# 28275          60.9        11.7          0.9            18.8             6.3
# 28276          57.9        12.8          1.1            21.7             3.4
# 28277          52.8        17.9          1.3            20.3             7.4
# 28278          53.3          13          1.5            27.5             2.3
# 28279          49.5        11.7            2            34.3             3.9
# 28280          56.9        13.1          1.3            22.6             4.5
# 28281          58.8        13.6          0.7            20.4             3.4
# 28282          61.5        10.7          0.8            17.7             4.6
#
#       DivorcedError SeparatedError NeverMarriedError          CountyName  \
# 1               0.8            0.3               0.8      Baldwin County
# 2               1.5            1.1               1.9      Barbour County
# 3               2.2            1.3               2.2         Bibb County
# 4               1.5            0.5               1.5       Blount County
# 5               2.8            2.0               4.7      Bullock County
# 6               2.0            0.9               1.8       Butler County
# 7               1.0            0.4               1.0      Calhoun County
# 8               1.5            0.8               1.7     Chambers County
# 9               1.6            0.6               2.6     Cherokee County
# 10              1.6            0.6               1.6      Chilton County
# 11              2.2            1.6               3.0      Choctaw County
# 12              1.6            1.1               1.8       Clarke County
# 13              2.3            1.0               2.5         Clay County
# 14              2.8            1.2               2.7     Cleburne County
# 15              1.3            0.6               1.3       Coffee County
# 16              1.2            0.5               1.0      Colbert County
# 17              2.4            0.7               4.0      Conecuh County
# 18              3.1            1.0               3.4        Coosa County
# 19              1.4            0.7               1.6    Covington County
# 20              2.0            0.9               2.0     Crenshaw County
# 21              1.3            0.5               1.2      Cullman County
# 22              1.1            0.4               1.8         Dale County
# 23              1.3            0.9               2.0       Dallas County
# 24              1.2            0.5               1.7       DeKalb County
# 25              0.9            0.5               0.9       Elmore County
# 26              1.2            0.6               1.4     Escambia County
# 27              0.9            0.4               0.9       Etowah County
# 28              1.8            0.8               2.5      Fayette County
# 29              1.7            0.7               1.8     Franklin County
# 30              2.0            0.8               1.6       Geneva County
# ...             ...            ...               ...                 ...
# 28253           0.9            0.3               1.1     Washburn County
# 28254           0.5            0.2               0.7   Washington County
# 28255           0.3            0.1               0.4     Waukesha County
# 28256           0.9            0.4                 1      Waupaca County
# 28257           0.9            0.2               0.9     Waushara County
# 28258           0.6            0.2               0.6    Winnebago County
# 28259           0.8            0.2                 1         Wood County
# 28260             1            0.2               1.2       Albany County
# 28261           1.6            0.6               2.3     Big Horn County
# 28262           1.5            0.7               1.8     Campbell County
# 28263           1.8            0.7               1.9       Carbon County
# 28264           2.7            0.4               2.5     Converse County
# 28265           2.4            0.2               3.1        Crook County
# 28266           1.1            0.4               1.2      Fremont County
# 28267           2.1            0.3                 2       Goshen County
# 28268           3.2            0.8               3.4  Hot Springs County
# 28269           3.4            0.4               2.5      Johnson County
# 28270           0.9            0.4               1.1      Laramie County
# 28271           2.3            0.8               2.1      Lincoln County
# 28272           1.1            0.4               1.1      Natrona County
# 28273           3.5              2               6.5     Niobrara County
# 28274           1.6            0.6               2.2         Park County
# 28275           2.8            1.1               3.8       Platte County
# 28276           1.7            0.5               2.1     Sheridan County
# 28277           5.8            1.5               3.5     Sublette County
# 28278           1.3            0.5               1.9   Sweetwater County
# 28279             3            1.4               3.2        Teton County
# 28280           2.4            0.8               2.9        Uinta County
# 28281           2.4            0.8               2.4     Washakie County
# 28282           2.4            0.7                 3       Weston County
#
#        StateName  Year
# 1        Alabama  2009
# 2        Alabama  2009
# 3        Alabama  2009
# 4        Alabama  2009
# 5        Alabama  2009
# 6        Alabama  2009
# 7        Alabama  2009
# 8        Alabama  2009
# 9        Alabama  2009
# 10       Alabama  2009
# 11       Alabama  2009
# 12       Alabama  2009
# 13       Alabama  2009
# 14       Alabama  2009
# 15       Alabama  2009
# 16       Alabama  2009
# 17       Alabama  2009
# 18       Alabama  2009
# 19       Alabama  2009
# 20       Alabama  2009
# 21       Alabama  2009
# 22       Alabama  2009
# 23       Alabama  2009
# 24       Alabama  2009
# 25       Alabama  2009
# 26       Alabama  2009
# 27       Alabama  2009
# 28       Alabama  2009
# 29       Alabama  2009
# 30       Alabama  2009
# ...          ...   ...
# 28253  Wisconsin  2017
# 28254  Wisconsin  2017
# 28255  Wisconsin  2017
# 28256  Wisconsin  2017
# 28257  Wisconsin  2017
# 28258  Wisconsin  2017
# 28259  Wisconsin  2017
# 28260    Wyoming  2017
# 28261    Wyoming  2017
# 28262    Wyoming  2017
# 28263    Wyoming  2017
# 28264    Wyoming  2017
# 28265    Wyoming  2017
# 28266    Wyoming  2017
# 28267    Wyoming  2017
# 28268    Wyoming  2017
# 28269    Wyoming  2017
# 28270    Wyoming  2017
# 28271    Wyoming  2017
# 28272    Wyoming  2017
# 28273    Wyoming  2017
# 28274    Wyoming  2017
# 28275    Wyoming  2017
# 28276    Wyoming  2017
# 28277    Wyoming  2017
# 28278    Wyoming  2017
# 28279    Wyoming  2017
# 28280    Wyoming  2017
# 28281    Wyoming  2017
# 28282    Wyoming  2017
#
# [28282 rows x 11 columns]

# %%
##### Send data to SQL
engine.execute('SELECT * FROM "MaritalStatus" limit 10').fetchall()
# Out:
# []
